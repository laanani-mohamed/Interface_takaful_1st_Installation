# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Ready/Encaissement_13-05-2026_17_09.csv',sep=';')
df.head()
# Out:
#   CodeIFC  NoPolice  NoAdhesion NomAssure NomContractant   DateEffet  \
# 0  ENCADE   12630.0    369443.0     JRIRI          JRIRI   2092024.0
# 1  ENCADE   19918.0    366122.0      GORY           GORY   1042026.0
# 2  ENCADE    5206.0    367959.0     RABIH          RABIH   1032023.0
# 3  ENCADE   16814.0    370784.0   BOUGGAR        BOUGGAR  29122025.0
# 4  ENCADE   19408.0    367329.0   MACHACH        MACHACH   1042026.0
#
#    DateEmission  DateEcheance  DateEnvoi  DateReglement  ...  Produit  \
# 0     3042026.0     2042026.0  2042026.0      2042026.0  ...    401.0
# 1    17032026.0     1042026.0  2042026.0      2042026.0  ...    400.0
# 2     3042026.0     1042026.0  2042026.0      2042026.0  ...    401.0
# 3     3042026.0    28032026.0  2042026.0      2042026.0  ...    400.0
# 4    30032026.0     1042026.0  2042026.0      2042026.0  ...    401.0
#
#    Support  ChampLettrage  Garantie  CompteTakaful    CritereCompte  Montant  \
# ...

# %%
df.isna().sum()
# Out:
# CodeIFC                         0
# NoPolice                       14
# NoAdhesion                     14
# NomAssure                      14
# NomContractant                 14
# DateEffet                   57879
# DateEmission                57879
# DateEcheance                57879
# DateEnvoi                   57879
# DateReglement               57865
# DateRetour                 161320
# DateComptaSUNEmission      161320
# DateComptaSUNAnnulation    161320
# IDBand                         14
# QuittanceNombreRepres          14
# DateTrxPeriod                   0
# TrxDate                         0
# TrxReference                    0
# TrxDescription                  0
# Agent                           0
# Produit                        14
# Support                        14
# ChampLettrage                  14
# Garantie                       14
# CompteTakaful                   0
# CritereCompte                   0
# Montant                         0
# ...
